# %% [markdown]
# # Урок 3. Системы управления базами данных MongoDB и SQLite в Python

# %% [markdown]
# 1) Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД
# 2) Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы
# 3*\) Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта

# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import urllib.parse
import re
from parce_vacancy import Vacancies
from pymongo import MongoClient
from pymongo import errors
import types

# %%
vacancies = Vacancies()
def to_db(self, what: list, where):
    """вставляет новые вакансии, обновляет все поля в уже существующих"""
    
    duplicates = []
    for element in what:
        element['_id'] = element['link'].split('/')[-1]
        if element['salary_min']:
            element['salary_min'] = int(element['salary_min'])
        if element['salary_max']:
            element['salary_max'] = int(element['salary_max'])
        try:
            where.insert_one(element)
        except errors.DuplicateKeyError:
            where.update_one({"_id": element['_id']}, {'$set': element})
            duplicates.append(element['_id'])
    
    if len(duplicates) > 0:
        print('duplicates were updated')
        
    #return duplicates
    
vacancies.to_db = types.MethodType(to_db, vacancies)

# %%
yourtext = 'python разработчик'
n_pages = 4
site = 'hh'

# %%
hh_vacancies = vacancies.find(yourtext, n_pages, site)
len(hh_vacancies)
# Out:
# 200

# %%
pprint(hh_vacancies[0])
# Out:
# {'address': 'Москва, Белорусская и еще 1 ',
#  'employer': ' Mindbox',
#  'link': 'https://hh.ru/vacancy/37022145',
#  'name': 'C# разработчик (начинающий, junior)',
#  'salary_currency': 'руб',
#  'salary_max': '140000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}

# %%
client = MongoClient('localhost', 27017)
db = client['vacancies']
hh = db.hh

# %%
vacancies.to_db(hh_vacancies, hh)
# Out:
# duplicates were updated

# %%
#поиск вакансий с окладом больше указанной суммы
number = 140000
to_show = {'name': 1, 'salary_min': 1, 'salary_max': 1}
for element in hh.find({'$or': [{'salary_min': { '$gte' : number } }, {'salary_max': { '$gte' : number } }]}, to_show ):
    pprint(element)
# Out:
# {'_id': '37022145',
#  'name': 'C# разработчик (начинающий, junior)',
#  'salary_max': 140000,
#  'salary_min': 100000}
# {'_id': '37036702',
#  'name': 'Старший специалист по тестированию ПО',
#  'salary_max': 150000,
#  'salary_min': None}
# {'_id': '36982786',
#  'name': 'Pre-Sales Engineer (Nexmo, the Vonage API Platform)',
#  'salary_max': None,
#  'salary_min': 180000}
# {'_id': '36680277',
#  'name': 'Программист Python',
#  'salary_max': 200000,
#  'salary_min': 160000}
# {'_id': '36876631',
#  'name': 'Разработчик Python / Django',
#  'salary_max': 200000,
#  'salary_min': 150000}
# {'_id': '37005696',
#  'name': 'Python разработчик',
#  'salary_max': 220000,
#  'salary_min': 170000}
# {'_id': '35503487',
#  'name': 'Python-разработчик',
#  'salary_max': 200000,
#  'salary_min': 140000}
# {'_id': '36267171',
#  'name': 'Python developer',
#  'salary_max': 200000,
#  'salary_min': 150000}
# {'_id': '36906273',
#  'name': 'Senior Python Developer',
#  'salary_max': None,
#  'salary_min': 180000}
# {'_id': '36444270',
#  'name': 'Senior Python Developer / Ведущий Python-разработчик',
#  'salary_max': None,
#  'salary_min': 200000}
# {'_id': '37005320',
#  'name': 'Backend python/Django разработчик',
#  'salary_max': 200000,
#  'salary_min': 120000}
# {'_id': '36756683',
#  'name': 'Python (Django) developer',
#  'salary_max': 180000,
#  'salary_min': None}
# {'_id': '36449432',
#  'name': 'Python middle developer',
#  'salary_max': 160000,
#  'salary_min': 120000}
# {'_id': '37058850',
#  'name': 'Back-end Python/Django разработчик',
#  'salary_max': 140000,
#  'salary_min': 90000}
# {'_id': '36916013',
#  'name': 'Разработчик Python Backend',
#  'salary_max': None,
#  'salary_min': 150000}
# {'_id': '37045645',
#  'name': 'Программист Python',
#  'salary_max': 200000,
#  'salary_min': None}
# {'_id': '36887804',
#  'name': 'Python-разработчик (Middle Python Developer)',
#  'salary_max': 230000,
#  'salary_min': None}
# {'_id': '37079761',
#  'name': 'Middle Frontend-разработчик',
#  'salary_max': 170000,
#  'salary_min': 150000}
# {'_id': '36769782',
#  'name': 'Разработчик Python (middle / senior) удалённо',
#  'salary_max': 140000,
#  'salary_min': 60000}
# {'_id': '36805018',
#  'name': 'Python middle developer',
#  'salary_max': 160000,
#  'salary_min': 120000}
# {'_id': '36693892',
#  'name': 'Senior C/C++ Developer',
#  'salary_max': None,
#  'salary_min': 150000}
# {'_id': '37014924',
#  'name': 'Инженер-программист (full stack)',
#  'salary_max': None,
#  'salary_min': 150000}
# {'_id': '37084032',
#  'name': 'Инженер-программист С/C++ для встраиваемых систем (Разработчик '
#          'C/C++)',
#  'salary_max': None,
#  'salary_min': 140000}
# {'_id': '36806210',
#  'name': 'C++ Senior Software Developer',
#  'salary_max': None,
#  'salary_min': 250000}
# {'_id': '36886946',
#  'name': 'Разработчик / Инженер-программист (Python)',
#  'salary_max': 230000,
#  'salary_min': None}
# {'_id': '37032727',
#  'name': 'Программист Python full stuck',
#  'salary_max': 150000,
#  'salary_min': 50000}
# {'_id': '37083764',
#  'name': 'Программист-алгоритмист по обработке изображений и компьютерному '
#          'зрению',
#  'salary_max': None,
#  'salary_min': 160000}
# {'_id': '35846205',
#  'name': 'Python senior developer',
#  'salary_max': 250000,
#  'salary_min': 180000}
# {'_id': '37030619',
#  'name': 'Backend Developer (Python, PostgreSQL)',
#  'salary_max': 200000,
#  'salary_min': 160000}
# {'_id': '36847348',
#  'name': 'Golang ведущий разработчик',
#  'salary_max': 300000,
#  'salary_min': 230000}
# {'_id': '35846186',
#  'name': 'Team lead Python developer',
#  'salary_max': 250000,
#  'salary_min': 180000}
# {'_id': '36307775',
#  'name': 'Junior / Middle iOS Developer',
#  'salary_max': 140000,
#  'salary_min': None}
# {'_id': '36906276',
#  'name': 'Программист по созданию и ведению обучающего курса по Python',
#  'salary_max': None,
#  'salary_min': 150000}
# {'_id': '32333890',
#  'name': 'PHP-разработчик',
#  'salary_max': 150000,
#  'salary_min': 130000}
# {'_id': '36858094',
#  'name': 'Senior iOS разработчик',
#  'salary_max': 350000,
#  'salary_min': 170000}
# {'_id': '34649894',
#  'name': 'Full-Stack Web-Developer (Python / Odoo)',
#  'salary_max': 200000,
#  'salary_min': 100000}
# {'_id': '37000256',
#  'name': 'Программист',
#  'salary_max': 150000,
#  'salary_min': 60000}
# {'_id': '36544967',
#  'name': 'Senior iOS Developer',
#  'salary_max': 300000,
#  'salary_min': 250000}
# {'_id': '36864336',
#  'name': 'Главный разработчик',
#  'salary_max': None,
#  'salary_min': 200000}
# {'_id': '36958305',
#  'name': 'Go/PHP developer',
#  'salary_max': 250000,
#  'salary_min': 120000}
# {'_id': '36858081',
#  'name': 'Android senior developer',
#  'salary_max': 350000,
#  'salary_min': 170000}
# {'_id': '36929281',
#  'name': 'Программист-Исследователь (RnD)',
#  'salary_max': 200000,
#  'salary_min': 100000}
# {'_id': '35275243',
#  'name': 'DevOps - разработчик ПО',
#  'salary_max': None,
#  'salary_min': 200000}
# {'_id': '36986668',
#  'name': 'Full-stack Developer',
#  'salary_max': 200000,
#  'salary_min': None}
# {'_id': '36870062',
#  'name': 'Scala/Java Developer',
#  'salary_max': 170000,
#  'salary_min': 120000}
# {'_id': '36718840',
#  'name': 'Ведущий разработчик ПО в области облачных технологий',
#  'salary_max': None,
#  'salary_min': 250000}
# {'_id': '36753903',
#  'name': 'Reverse Engineer / Вирусный аналитик / Реверc инженер',
#  'salary_max': 300000,
#  'salary_min': None}
# {'_id': '36935593',
#  'name': 'QA инженер - тестировщик',
#  'salary_max': 140000,
#  'salary_min': 70000}
# {'_id': '36416362',
#  'name': 'Senior Python Разработчик',
#  'salary_max': 250000,
#  'salary_min': None}
# {'_id': '36354015',
#  'name': 'Spark data engineer',
#  'salary_max': 300000,
#  'salary_min': 130000}
# {'_id': '36852550',
#  'name': 'Программист Oracle',
#  'salary_max': 200000,
#  'salary_min': 150000}
# {'_id': '36863064',
#  'name': 'Python-разработчик (Django, DRF)',
#  'salary_max': 150000,
#  'salary_min': 60000}
# {'_id': '36723154',
#  'name': 'Разработчик С++',
#  'salary_max': 170000,
#  'salary_min': None}
# {'_id': '35219728',
#  'name': 'DevOps engineer',
#  'salary_max': 170000,
#  'salary_min': 120000}
# {'_id': '36867880',
#  'name': 'Senior Unity Developer (C#)',
#  'salary_max': 150000,
#  'salary_min': 50000}
# {'_id': '36817034',
#  'name': 'Senior Python Developer',
#  'salary_max': 250000,
#  'salary_min': 180000}
# {'_id': '36319808',
#  'name': 'Системный администратор Linux',
#  'salary_max': None,
#  'salary_min': 140000}
# {'_id': '36867799',
#  'name': 'Senior Android Developer (C#)',
#  'salary_max': 150000,
#  'salary_min': 50000}
# {'_id': '36858501',
#  'name': 'Инженер DevOps',
#  'salary_max': 200000,
#  'salary_min': None}
# {'_id': '36774724',
#  'name': 'Системный разработчик С/С++/Rust',
#  'salary_max': 200000,
#  'salary_min': 120000}
# {'_id': '36611477',
#  'name': 'Frontend Developer',
#  'salary_max': 200000,
#  'salary_min': 100000}
# {'_id': '36890649',
#  'name': 'Ведущий системный администратор Linux',
#  'salary_max': None,
#  'salary_min': 180000}
# {'_id': '31648507',
#  'name': 'Senior Product / Data Analyst',
#  'salary_max': None,
#  'salary_min': 200000}
